# %%
from pyecharts.charts import Funnel
from pyecharts.charts import Grid
import pyecharts.options as opts
import pandas as pd
import random

dataset = pd.read_csv('D:\广商网课\\resource\\12-16.csv')

random_date = random.choices(dataset['time'])
random_stock = dataset[(dataset['time'] == random_date[0])][['BK300_name', 'closing']]
random_stock = random_stock.sample(5)

random_stock.sort_values(by='closing', inplace=True, ascending=False)

x_data = random_stock['BK300_name'].to_list()
y_data = random_stock['closing'].to_list()

data = [[x_data[i], y_data[i]] for i in range(len(x_data))]

e_x_data = random_stock['BK300_name'].to_list()
e_y_data = [100, 80, 60, 40, 20]

ex_data = [[e_x_data[i], e_y_data[i]] for i in range(len(e_x_data))]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-cfc5e8094b4d> in <module>
# ----> 1 from pyecharts.charts import Funnel
#       2 from pyecharts.charts import Grid
#       3 import pyecharts.options as opts
#       4 import pandas as pd
#       5 import random
#
# ModuleNotFoundError: No module named 'pyecharts'

# %%
funnel = (
    Funnel(init_opts=opts.InitOpts(width="1600px", height="800px"))
    .add(
        series_name="expected",
        data_pair=ex_data,
        gap=2,
        tooltip_opts=opts.TooltipOpts(trigger="item", formatter="{a} <br/>{b} : {c}%"),
        label_opts=opts.LabelOpts(is_show=True, position="inside"),
        itemstyle_opts=opts.ItemStyleOpts(border_color="#fff", border_width=1, opacity=0.5),
    )
)

# %%
funnel1 = (
    Funnel(init_opts=opts.InitOpts(width="1600px", height="800px"))
    .add(
        series_name="AAA",
        data_pair=data,
        gap=2,
        tooltip_opts=opts.TooltipOpts(trigger="item"),
        label_opts=opts.LabelOpts(is_show=True, position="top"),
        itemstyle_opts=opts.ItemStyleOpts(border_color="#fff", border_width=1, opacity=0.7),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="%s收市价格漏斗图" % random_date[0], subtitle="芜湖~"))

)

grid = (
    Grid()
    .add(funnel1, opts.GridOpts(pos_left="50%", pos_right="50%"), is_control_axis_index=True)
    .add(funnel, opts.GridOpts(pos_left="50%", pos_right="50%"), is_control_axis_index=True)

)

# %%
grid.load_javascript()
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="bde374363ee340c3a380adb5ddcee59a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_bde374363ee340c3a380adb5ddcee59a = echarts.init(
#                     document.getElementById('bde374363ee340c3a380adb5ddcee59a'), 'white', {renderer: 'canvas'});
#                 var option_bde374363ee340c3a380adb5ddcee59a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "AAA",
#             "data": [
#                 {
#                     "name": "\u540c\u82b1\u987a",
#                     "value": 108.14
#                 },
#                 {
#                     "name": "\u5317\u65b9\u534e\u521b",
#                     "value": 36.8
#                 },
#                 {
#                     "name": "\u56fd\u6295\u8d44\u672c",
#                     "value": 28.22
#                 },
#                 {
#                     "name": "\u4e2d\u56fd\u8054\u901a",
#                     "value": 8.52
#                 },
#                 {
#                     "name": "\u4e2d\u4fe1\u94f6\u884c",
#                     "value": 7.35
#                 }
#             ],
#             "sort": "descending",
#             "gap": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             },
#             "itemStyle": {
#                 "borderColor": "#fff",
#                 "borderWidth": 1,
#                 "opacity": 0.7
#             }
#         },
#         {
#             "type": "funnel",
#             "name": "expected",
#             "data": [
#                 {
#                     "name": "\u540c\u82b1\u987a",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u5317\u65b9\u534e\u521b",
#                     "value": 80
#                 },
#                 {
#                     "name": "\u56fd\u6295\u8d44\u672c",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u4e2d\u56fd\u8054\u901a",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u4e2d\u4fe1\u94f6\u884c",
#                     "value": 20
#                 }
#             ],
#             "sort": "descending",
#             "gap": 2,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "formatter": "{a} <br/>{b} : {c}%",
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             },
#             "itemStyle": {
#                 "borderColor": "#fff",
#                 "borderWidth": 1,
#                 "opacity": 0.5
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u540c\u82b1\u987a",
#                 "\u4e2d\u56fd\u8054\u901a",
#                 "\u5317\u65b9\u534e\u521b",
#                 "\u4e2d\u4fe1\u94f6\u884c",
#                 "\u56fd\u6295\u8d44\u672c"
#             ],
#             "selected": {
#                 "\u540c\u82b1\u987a": true,
#                 "\u5317\u65b9\u534e\u521b": true,
#                 "\u56fd\u6295\u8d44\u672c": true,
#                 "\u4e2d\u56fd\u8054\u901a": true,
#                 "\u4e2d\u4fe1\u94f6\u884c": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         },
#         {
#             "data": [
#                 "\u540c\u82b1\u987a",
#                 "\u4e2d\u56fd\u8054\u901a",
#                 "\u5317\u65b9\u534e\u521b",
#                 "\u4e2d\u4fe1\u94f6\u884c",
#                 "\u56fd\u6295\u8d44\u672c"
#             ],
#             "selected": {
#                 "\u540c\u82b1\u987a": true,
#                 "\u5317\u65b9\u534e\u521b": true,
#                 "\u56fd\u6295\u8d44\u672c": true,
#                 "\u4e2d\u56fd\u8054\u901a": true,
#                 "\u4e2d\u4fe1\u94f6\u884c": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "2015-05-15\u6536\u5e02\u4ef7\u683c\u6f0f\u6597\u56fe",
#             "subtext": "\u829c\u6e56~",
#             "padding": 5,
#             "itemGap": 10
#         },
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "grid": [
#         {
#             "left": "50%",
#             "right": "50%",
#             "containLabel": false
#         },
#         {
#             "left": "50%",
#             "right": "50%",
#             "containLabel": false
#         }
#     ]
# };
#                 chart_bde374363ee340c3a380adb5ddcee59a.setOption(option_bde374363ee340c3a380adb5ddcee59a);
#         });
#     </script>

# %%
import pandas_bokeh
pandas_bokeh.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
dataset['time'] = pd.to_datetime(dataset['time'], format='%Y-%m-%d')

next_5_data = dataset[(dataset['time'] >= '2021-12-1')]

random_name = random.choices(dataset['BK300_name'].tolist())[0]

next_5_data = next_5_data.loc[next_5_data['BK300_name'] == random_name]

next_5_data['time'] = next_5_data['time'].astype(str)
next_5_data['closing'] = next_5_data['closing'].astype("float64")

# %%
p = next_5_data.plot_bokeh(
    kind='line',
    x='time',
    y='closing',
    xlabel='date',
    ylabel='close price',
    title='one month close price by %s' % random_name,
    show_figure=False,
    figsize=(1000, 800)
)

q = next_5_data.plot_bokeh(
    kind='bar',
    x='time',
    y='vol',
    xlabel='date',
    ylabel='close price',
    title='one month vol by %s' % random_name,
    show_figure=False,
    figsize=(1000, 800)
)

# %%
pandas_bokeh.plot_grid([[p, q]])
# Out:
#   <div class="bk-root" id="29c916ec-a20c-4131-9020-96d631cc79f7" data-root-id="1174"></div>
# Column(id='1174', ...)

# %%
import pyqtgraph
